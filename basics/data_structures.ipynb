# %% [markdown]
# # Tuple

# %%
class A:
    def __init__(self):
        self.val = 5

a = A()
t = (1, 'a', a) # a is a refernce to an instance
t
# Out:
# (1, 'a', <__main__.A at 0x252c2da1be0>)

# %%
a.val = 3 # the instance value can be changed

# %%
t
# Out:
# (1, 'a', <__main__.A at 0x252c2da1be0>)

# %%
t[2], t[2].val
