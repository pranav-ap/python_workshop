# %%
from plotnine import *
from plotnine.data import anscombe_quartet

# %%
anscombe_quartet.head(3)
# Out:
#   dataset   x     y
# 0       I  10  8.04
# 1       I   8  6.95
# 2       I  13  7.58

# %%
(
    ggplot(anscombe_quartet, aes("x", "y", color="dataset"))
    + geom_point()
    + geom_smooth(method="lm", se=False, fullrange=True)
    + facet_wrap("dataset")
)
